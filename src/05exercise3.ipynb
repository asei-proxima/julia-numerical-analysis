# %%
Δt = 0.01

function Euler(u)
    return u + Δt * (- √u )
end
# Out:
# Euler (generic function with 1 method)

# %%
u = 0.25
sq = [u]

for n in 1:1000
    println("$n : $u , $(-√u)")
    u = Euler(u)
    push!(sq, u)
end
# Out:
# 1 : 0.25 , -0.5
# 2 : 0.245 , -0.4949747468305833
# 3 : 0.24005025253169415 , -0.4899492346475236
# 4 : 0.2351507601852189 , -0.4849234580686099
# 5 : 0.23030152560453282 , -0.4798974115418136
# 6 : 0.2255025514891147 , -0.4748710893380589
# 7 : 0.2207538405957341 , -0.4698444855436042
# 8 : 0.21605539574029806 , -0.4648175940520088
# 9 : 0.21140721979977797 , -0.459790408555657
# 10 : 0.2068093157142214 , -0.45476292253681083
# 11 : 0.2022616864888533 , -0.44973512925815934
# 12 : 0.1977643351962717 , -0.44470702175282967
# 13 : 0.1933172649787434 , -0.4396785928138228
# 14 : 0.1889204790506052 , -0.43464983498283444
# 15 : 0.18457398070077685 , -0.42962074053841587
# 16 : 0.18027777329539268 , -0.4245913014834297
# 17 : 0.1760318602805584 , -0.4195615095317472
# 18 : 0.17183624518524093 , -0.41453135609413305
# 19 : 0.1676909316242996 , -0.40950083226325634
# 20 : 0.16359592330166703 , -0.40446992879776245
# 21 : 0.1595512240136894 , -0.399438636105334
# ...

# %%
using Plots
Rx = 0.0:Δt:300*Δt # 範囲というやつだね

plot(Rx, sq)
xaxis!("time t")
yaxis!("u")
